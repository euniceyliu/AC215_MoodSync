# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
import zipfile
import os
import json
import re
from html.parser import HTMLParser
import csv
import json

# %% [markdown]
# # Attain and Load the genius.com data

# %%
# used for cleaning up the genius annotation and lyrics

class MyHTMLParser(HTMLParser):
    def __init__(self):
        super().__init__()
        self.capture = False
        self.captured_data = []

    def handle_starttag(self, tag, attrs):
        if tag == 'p':
            self.capture = True

    def handle_endtag(self, tag):
        if tag == 'p':
            self.capture = False

    def handle_data(self, data):
        if self.capture:
            self.captured_data.append(data)

def parse_content(html_content):
    parser = MyHTMLParser()
    parser.feed(html_content)
    return parser.captured_data

# %%
# these function attained from https://github.com/cptq/genius-expertise/tree/master/data
# of how to load the annotation data, song data and the lyrics data

def load_annotation_info(reviewed=True, max_lines=100):
    annotation_info = []
    with open("/content/gdrive/My Drive/AC215 Project/annotation_info.json", 'r') as f:
        for i, line in enumerate(f):
            j = json.loads(line)
            # only choose the annotation that is verified by the artist
            if reviewed and j['type'] == 'verified':
                annotation_info.append(j)
            elif not reviewed:
                annotation_info.append(j)
    return annotation_info



def song_info_gen():
    ''' Loads song information.'''
    with open(f'/content/gdrive/My Drive/AC215 Project/song_info.json', 'r') as f:
        song_info = f.readlines()
        song_info = map(json.loads, song_info)
    return song_info


def lyrics_info_gen():
    '''lyrics information generator.'''
    with open(f'/content/gdrive/My Drive/AC215 Project/lyrics.jl', 'r') as f:
        lyrics_info = f.readlines()
    return map(json.loads, lyrics_info)

# %% [markdown]
# # Annotation Data

# %%
annotations = load_annotation_info(reviewed=True, max_lines=100)
len(annotations)
# Out:
# 8547

# %%
# Path to save the CSV file
csv_file_path = '/content/gdrive/My Drive/AC215 Project/annotations.csv'

# Writing to a CSV file
with open(csv_file_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=["Artist", "Song", "Lyrics", "Annotation"])
    writer.writeheader()
    for annotation in annotations:
        # clean up the annotation
        p_content = parse_content(annotation["content"])
        # print(p_content)
        for content in p_content:
            # print(content)
            writer.writerow({
                "Artist": annotation["artist"],
                "Song": annotation["song"],
                "Lyrics": annotation["lyrics"],
                "Annotation": content
            })

print(f'Data has been written to {csv_file_path}')
# Out:
# Data has been written to /content/gdrive/My Drive/AC215 Project/annotations.csv

# %%
csv_file_path = '/content/gdrive/My Drive/AC215 Project/annotations.csv'
df = pd.read_csv(csv_file_path)
df
# Out:
#               Artist                                        Song  \
# 0      KendrickLamar  Kendrick-lamar-swimming-pools-drank-lyrics
# 1      KendrickLamar  Kendrick-lamar-swimming-pools-drank-lyrics
# 2      KendrickLamar           Kendrick-lamar-money-trees-lyrics
# 3            JayRock           Kendrick-lamar-money-trees-lyrics
# 4            JayRock           Kendrick-lamar-money-trees-lyrics
# ...              ...                                         ...
# 15546            BBP                             Pnl-naha-lyrics
# 15547            BBP         Pnl-je-thaine-version-orange-lyrics
# 15548            BBP         Pnl-je-thaine-version-orange-lyrics
# 15549            BBP         Pnl-je-thaine-version-orange-lyrics
# 15550            BBP         Pnl-je-thaine-version-orange-lyrics
#
#                                                   Lyrics  \
# 0      Now I done grew up 'round some people livin' t...
# 1                        Backstroke every day in Chicago
# 2      I fucked Sherane and went to tell my bros (tel...
# 3                                    [Verse 3: Jay Rock]
# 4      Imagine Rock up in them projects\nWhere them n...
# ...                                                  ...
# 15546                                  [Produit par BBP]
# 15547                                  [Produit par BBP]
# 15548                                  [Produit par BBP]
# 15549                                  [Produit par BBP]
# 15550                                  [Produit par BBP]
#
#                                               Annotation
# 0      This song is about me reminising about my year...
# 1      back stroke. playing on the word swimming pool...
# 2      That was a metaphor for both. Not saying that ...
# 3      I first heard the record before it dropped, ri...
# 4      Moving out the projects was hard. That’s home....
# ...                                                  ...
# 15546  J'ai fais plein de prods, je leur ai envoyé et...
# 15547  À la base j'avais fait cette prod séparément, ...
# 15548                                               Vald
# 15549  , mais son DA la trouvait “sans intérêt”. Du c...
# 15550  Quand le medley a fuité, je ne l'ai pas entend...
#
# [15551 rows x 4 columns]

# %% [markdown]
# # Song Data

# %%
song_info = song_info_gen()

# %%
song_info_list = list(song_info)

# %%
song_info_df = pd.DataFrame(song_info_list)
song_info_df.head()
# Out:
#                                      url_name                   title  \
# 0  Kendrick-lamar-swimming-pools-drank-lyrics  Swimming Pools (Drank)
# 1           Kendrick-lamar-money-trees-lyrics             Money Trees
# 2                   Kendrick-lamar-xxx-lyrics                    XXX.
# 3           A-ap-rocky-fuckin-problems-lyrics        Fuckin’ Problems
# 4                   Kendrick-lamar-dna-lyrics                    DNA.
#
#    primary_artist      release_date  pyongs  contributors  has_bio      views  \
# 0  Kendrick-lamar     July 31, 2012   894.0           403     True  5589280.0
# 1  Kendrick-lamar  October 22, 2012   880.0           394     True  4592003.0
# 2  Kendrick-lamar    April 14, 2017   188.0           389     True  4651514.0
# 3      A-ap-rocky  October 24, 2012   706.0           437     True  7378309.0
# 4  Kendrick-lamar    April 14, 2017   555.0           570     True  5113687.0
#
#                                                 tags  annotations
# 0  [Trap, Conscious Hip-Hop, Memes, West Coast, R...          NaN
# 1     [Conscious Hip-Hop, West Coast, Rap, Producer]          NaN
# 2  [Conscious Hip-Hop, Boom Bap, Pop, West Coast,...          NaN
# 3  [Gangsta Rap, Dirty South, Atlanta, Posse Cut,...          NaN
# 4  [Politics, Producer, News, Conscious Hip-Hop, ...          NaN

# %% [markdown]
# # Lyrics Data

# %%
lyrics_info = lyrics_info_gen()

# %%
lyrics_info = list(lyrics_info)
lyrics_info_df = pd.DataFrame(lyrics_info)
lyrics_info_df["lyrics"]
# Out:
# 0        \n\n[Produced by T-Minus]\n\n[Intro]\nPour up ...
# 1        \n\n[Produced by DJ Dahi]\n\n[Verse 1: Kendric...
# 2        \n\n[Intro: Bēkon & Kid Capri]\nAmerica, God b...
# 3        \n\n[Chorus: 2 Chainz, Drake & Both (A$AP Rock...
# 4        \n\n[Verse 1]\nI got, I got, I got, I got—\nLo...
#                                ...
# 37988    \n\n[Intro : N.O.S.]\nOuais, ouais, ouais, oua...
# 37989    \n\n[Couplet 1 : Ademo]\nChang, chang, chang, ...
# 37990    \n\n[Intro: N.O.S]\nOuais, Ah on va voir\nOuai...
# 37991    \n\n[Produit par BBP]\n\n[Couplet 1 : Ademo]\n...
# 37992    \n\n[Verse 1: Drake]\nAyy, wild things you're ...
# Name: lyrics, Length: 37993, dtype: object

# %%
def clean_lyrics_dataset(df):
    def clean_text(text):
        if not isinstance(text, str):
            return text

        # Remove literal '\n' strings
        text = text.replace('\\n', ' ')

        # Remove section headers in brackets
        text = re.sub(r'\[[^\]]*\]', '', text)

        # Remove special characters and numbers
        text = re.sub(r'\*+\d+\*+', '', text)
        text = re.sub(r'\*\*\d+\*\*', '', text)

        # Remove producer tags
        text = re.sub(r'\[Produit par[^\]]*\]', '', text)

        # Replace all types of newlines with spaces
        text = text.replace('\n', ' ')
        text = text.replace('\r', ' ')

        # Remove extra spaces
        text = re.sub(r'\s+', ' ', text)

        return text.strip()

    # Create a copy to avoid modifying the original
    cleaned_df = df.copy()

    # Apply cleaning to the lyrics column
    cleaned_df["lyrics"] = cleaned_df["lyrics"].apply(clean_text)

    return cleaned_df

# %%
cleaned_lyrics = clean_lyrics_dataset(lyrics_info_df)
cleaned_lyrics
# Out:
#                                                     song  \
# 0             Kendrick-lamar-swimming-pools-drank-lyrics
# 1                      Kendrick-lamar-money-trees-lyrics
# 2                              Kendrick-lamar-xxx-lyrics
# 3                      A-ap-rocky-fuckin-problems-lyrics
# 4                              Kendrick-lamar-dna-lyrics
# ...                                                  ...
# 37988                           Pnl-tchiki-tchiki-lyrics
# 37989                                   Pnl-chang-lyrics
# 37990                                   Pnl-simba-lyrics
# 37991                Pnl-je-thaine-version-orange-lyrics
# 37992  Drake-and-michael-jackson-dont-matter-to-me-ly...
#
#                                                   lyrics
# 0      Pour up (Drank), head shot (Drank) Sit down (D...
# 1      Uh, me and my niggas tryna get it, ya bish (ya...
# 2      America, God bless you if it's good to you Ame...
# 3      I love bad bitches, that's my fuckin' problem ...
# 4      I got, I got, I got, I got— Loyalty, got royal...
# ...                                                  ...
# 37988  Ouais, ouais, ouais, ouais, ouais J'sens l'ode...
# 37989  Chang, chang, chang, j'marche sur la muraille ...
# 37990  Ouais, Ah on va voir Ouais, ouais Et ça r'comm...
# 37991  Que dire à part que ça pue dans la street à pa...
# 37992  Ayy, wild things you're doin' at night Trips t...
#
# [37993 rows x 2 columns]

# %% [markdown]
# # Combine Song, Lyrics and Annotation

# %%
song_info_df['url_name'] = song_info_df['url_name'].astype("string")
df['Song'] = df['Song'].astype("string").str.replace(" ","")
song_info_df['url_name'] = song_info_df['url_name'].astype("string").str.replace(" ","")

# %%
combined = df.merge(song_info_df, how='left', left_on='Song', right_on='url_name')

# %%
combined.head()
# Out:
#           Artist                                        Song  \
# 0  KendrickLamar  Kendrick-lamar-swimming-pools-drank-lyrics
# 1  KendrickLamar  Kendrick-lamar-swimming-pools-drank-lyrics
# 2  KendrickLamar           Kendrick-lamar-money-trees-lyrics
# 3        JayRock           Kendrick-lamar-money-trees-lyrics
# 4        JayRock           Kendrick-lamar-money-trees-lyrics
#
#                                               Lyrics  \
# 0  Now I done grew up 'round some people livin' t...
# 1                    Backstroke every day in Chicago
# 2  I fucked Sherane and went to tell my bros (tel...
# 3                                [Verse 3: Jay Rock]
# 4  Imagine Rock up in them projects\nWhere them n...
#
#                                           Annotation  \
# 0  This song is about me reminising about my year...
# 1  back stroke. playing on the word swimming pool...
# 2  That was a metaphor for both. Not saying that ...
# 3  I first heard the record before it dropped, ri...
# 4  Moving out the projects was hard. That’s home....
#
#                                      url_name                   title  \
# 0  Kendrick-lamar-swimming-pools-drank-lyrics  Swimming Pools (Drank)
# 1  Kendrick-lamar-swimming-pools-drank-lyrics  Swimming Pools (Drank)
# 2           Kendrick-lamar-money-trees-lyrics             Money Trees
# 3           Kendrick-lamar-money-trees-lyrics             Money Trees
# 4           Kendrick-lamar-money-trees-lyrics             Money Trees
#
#    primary_artist      release_date  pyongs  contributors has_bio      views  \
# 0  Kendrick-lamar     July 31, 2012   894.0         403.0    True  5589280.0
# 1  Kendrick-lamar     July 31, 2012   894.0         403.0    True  5589280.0
# 2  Kendrick-lamar  October 22, 2012   880.0         394.0    True  4592003.0
# 3  Kendrick-lamar  October 22, 2012   880.0         394.0    True  4592003.0
# 4  Kendrick-lamar  October 22, 2012   880.0         394.0    True  4592003.0
#
#                                                 tags  annotations
# 0  [Trap, Conscious Hip-Hop, Memes, West Coast, R...          NaN
# 1  [Trap, Conscious Hip-Hop, Memes, West Coast, R...          NaN
# 2     [Conscious Hip-Hop, West Coast, Rap, Producer]          NaN
# 3     [Conscious Hip-Hop, West Coast, Rap, Producer]          NaN
# 4     [Conscious Hip-Hop, West Coast, Rap, Producer]          NaN

# %%
cleaned_lyrics['song'] = cleaned_lyrics['song'].astype("string").str.replace(" ","")

# %%
cleaned_lyrics['song'] = cleaned_lyrics['song'].astype("string").str.replace(" ","")
combined_final = combined.merge(cleaned_lyrics, how='left', left_on='Song', right_on='song')
combined_final
# Out:
#               Artist                                        Song  \
# 0      KendrickLamar  Kendrick-lamar-swimming-pools-drank-lyrics
# 1      KendrickLamar  Kendrick-lamar-swimming-pools-drank-lyrics
# 2      KendrickLamar           Kendrick-lamar-money-trees-lyrics
# 3            JayRock           Kendrick-lamar-money-trees-lyrics
# 4            JayRock           Kendrick-lamar-money-trees-lyrics
# ...              ...                                         ...
# 15546            BBP                             Pnl-naha-lyrics
# 15547            BBP         Pnl-je-thaine-version-orange-lyrics
# 15548            BBP         Pnl-je-thaine-version-orange-lyrics
# 15549            BBP         Pnl-je-thaine-version-orange-lyrics
# 15550            BBP         Pnl-je-thaine-version-orange-lyrics
#
# ...                                                  ...
# 15546               [Cloud Rap, French Rap, France, Rap]
# 15547               [Cloud Rap, French Rap, France, Rap]
# 15548               [Cloud Rap, French Rap, France, Rap]
# 15549               [Cloud Rap, French Rap, France, Rap]
# 15550               [Cloud Rap, French Rap, France, Rap]
#
#                                              lyrics_full
# 0      Pour up (Drank), head shot (Drank) Sit down (D...
# 1      Pour up (Drank), head shot (Drank) Sit down (D...
# 2      Uh, me and my niggas tryna get it, ya bish (ya...
# 3      Uh, me and my niggas tryna get it, ya bish (ya...
# 4      Uh, me and my niggas tryna get it, ya bish (ya...
# ...                                                  ...
# 15546  Mes gouttes de sueur ont l'odeur d'l'Enfer Ça ...
# 15547  Que dire à part que ça pue dans la street à pa...
# 15548  Que dire à part que ça pue dans la street à pa...
# 15549  Que dire à part que ça pue dans la street à pa...
# 15550  Que dire à part que ça pue dans la street à pa...
#
# [15551 rows x 7 columns]

# %%
combined_final.to_csv("/content/gdrive/My Drive/AC215 Project/combined_df.csv")

# %%
combined_final = pd.read_csv("/content/gdrive/My Drive/AC215 Project/combined_df.csv")

# %%
combined_final.primary_artist.nunique()
# Out:
# 609

# %%
combined_final.tags
# Out:
# 0        [Trap, Conscious Hip-Hop, Memes, West Coast, R...
# 1        [Trap, Conscious Hip-Hop, Memes, West Coast, R...
# 2           [Conscious Hip-Hop, West Coast, Rap, Producer]
# 3           [Conscious Hip-Hop, West Coast, Rap, Producer]
# 4           [Conscious Hip-Hop, West Coast, Rap, Producer]
#                                ...
# 15546                 [Cloud Rap, French Rap, France, Rap]
# 15547                 [Cloud Rap, French Rap, France, Rap]
# 15548                 [Cloud Rap, French Rap, France, Rap]
# 15549                 [Cloud Rap, French Rap, France, Rap]
# 15550                 [Cloud Rap, French Rap, France, Rap]
# Name: tags, Length: 15551, dtype: object

# %%
# Summarize the dataset
combined_final.describe()
# Out:
#        primary_artist Annotation     Lyrics  \
# count           15549      15551      15461
# unique            609      12351       7716
# top           Pusha-t         \n  [Verse 1]
# freq              467       1236        112
#
#                                                     title        release_date  \
# count                                               15549               14636
# unique                                               1989                1100
# top     Age Ain’t Nothing But A Number To Write Lyrics...  September 18, 2015
# freq                                                  195                 180
#
#          tags                                        lyrics_full
# count   15549                                              15551
# unique    599                                               2028
# top     [Rap]  SCENE. NEW YORK CITY. TAXI. Enter SUPERFLYRONA...
# freq     6347                                                195

# %%
combined_final.isnull().sum()
# Out:
# primary_artist      2
# Annotation          0
# Lyrics             90
# title               2
# release_date      915
# tags                2
# lyrics_full         0
# dtype: int64

# %%
combined_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15551 entries, 0 to 15550
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0